# %% [markdown]
# <a href="https://colab.research.google.com/github/x1001000/Colab-Notebooks/blob/main/Bright_Data_Browser_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install playwright --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 MB 12.9 MB/s eta 0:00:00

# %%
AUTH = 'USERNAME:PASSWORD'
browser_api_endpoint = f'wss://{AUTH}@brd.superproxy.io:9222'

# %%
import asyncio
from os import environ
from playwright.async_api import Playwright, async_playwright

async def scrape(playwright: Playwright, url):
    print('Connecting to Browser...')
    browser = await playwright.chromium.connect_over_cdp(browser_api_endpoint)
    try:
        print(f'Connected! Navigating to {url}...')
        page = await browser.new_page()
        await page.goto(url, timeout=2*60_000)
        print('Navigated! Scraping page content...')
        data = await page.content()
        print(f'Scraped! Data: {data}')
    finally:
        await browser.close()

# %%
async with async_playwright() as playwright:
    await scrape(playwright, 'https://www.macrotrends.net/stock-data/MRVL/revenue/Q')
# Out:
# Connecting to Browser...
# Connected! Navigating to https://www.macrotrends.net/stock-data/MRVL/revenue/Q...
# Navigated! Scraping page content...
# ...

# %%
async with async_playwright() as playwright:
    await scrape(playwright, 'https://psa.gov.ph/statistics/national-accounts/data-series')
# Out:
# Connecting to Browser...
# Connected! Navigating to https://psa.gov.ph/statistics/national-accounts/data-series...
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /tmp/ipython-input-927148167.py in <cell line: 1>()
#       1 async with async_playwright() as playwright:
# ----> 2     await scrape(playwright, 'https://psa.gov.ph/statistics/national-accounts/data-series')
#
# /tmp/ipython-input-710243654.py in scrape(playwright, url)
#       9         print(f'Connected! Navigating to {url}...')
#      10         page = await browser.new_page()
# ---> 11         await page.goto(url, timeout=2*60_000)
#      12         print('Navigated! Scraping page content...')
#      13         data = await page.content()
#
# /usr/local/lib/python3.12/dist-packages/playwright/async_api/_generated.py in goto(self, url, timeout, wait_until, referer)
#    9039
# ...
