# %% [markdown]
# <a href="https://colab.research.google.com/github/x1001000/Colab-Notebooks/blob/main/HTML_in_Markdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
response_text = '''
<p>針對您詢問過去兩年（2024 - 2026 年初）美國 S&P 500 企業電話會議的關鍵字提及次數，我們透過量化分析財報逐字稿發現，市場焦點已從「通膨與衰退」轉向「<strong>AI 變現能力</strong>」與「<strong>關稅政策衝擊</strong>」。</p>
<p>以下根據最新數據與我們研究員的分析，為您整理關鍵趨勢：</p>
<h3>一、 核心關鍵字提及次數趨勢</h3>
<p>在過去兩年的財報季中，企業高層最關注的三大主題分別為：人工智慧、關稅與選舉。這反映了企業在技術轉型與政策變動雙重壓力下的應對策略。</p>
<table>
<thead>
<tr>
<th>關鍵字主題</th>
<th>前值 (2025-07-01)</th>
<th>最新數據 (2025-10-01)</th>
<th>趨勢分析</th>
</tr>
</thead>
<tbody>
<tr>
<td><strong><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/115843/us-sp500-earning-call-keyword-ai">人工智慧 (AI)</a></strong></td>
<td>10.89 次</td>
<td><strong>11.16 次</strong></td>
<td>持續攀升，顯示 AI 已從實驗轉向核心戰略。</td>
</tr>
<tr>
<td><strong><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/120339/us-sp500-earning-call-keyword-tariff">關稅 (Tariff)</a></strong></td>
<td>4.35 次</td>
<td><strong>3.35 次</strong></td>
<td>處於歷史高位，企業高度關注貿易保護主義。</td>
</tr>
<tr>
<td><strong><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/115859/us-sp500-earning-call-keyword-election">選舉 (Election)</a></strong></td>
<td>0.12 次</td>
<td><strong>0.15 次</strong></td>
<td>隨政治局勢變動，提及頻率逐步墊高。</td>
</tr>
</tbody>
</table>
<p><em>註：數據為 S&amp;P 500 平均每家公司提及次數。</em></p>
<h3>二、 產業關注點分化</h3>
<p>不同產業對議題的敏感度顯著不同。我們觀察到 AI 需求正從科技端外溢至傳產，而關稅則成為工業與公用事業的成本隱憂。</p>
<h4>1. 人工智慧 (AI)：從雲端擴散至應用端</h4>
<ul>
<li><strong><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/114367/us-the-number-of-mentions-of-ai-in-all-industry">資訊科技類股</a></strong> 依然是提及次數最多的產業（<strong>36.84 次</strong>），但相較於前一季的 43.63 次略有回落，主因市場開始嚴格審視 AI 的回報率（ROI）。</li>
<li><strong><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/114367/us-the-number-of-mentions-of-ai-in-all-industry">通訊服務類股</a></strong> 次之，提及次數成長至 <strong>22.00 次</strong>，主要受 Meta 等巨頭強調 AI 提升廣告精準度帶動。</li>
<li><strong><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/114367/us-the-number-of-mentions-of-ai-in-all-industry">醫療保健</a></strong> 成長最為顯著，從 3.50 次翻倍至 <strong>6.38 次</strong>，反映 AI 在藥物研發上的潛力。</li>
</ul>
<h4>2. 關稅 (Tariff)：供應鏈韌性的挑戰</h4>
<ul>
<li><strong><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/120340/us-the-number-of-mentions-of-tariff-in-all-industry">公用事業</a></strong> 提及次數爆發式成長，從 3.48 次飆升至 <strong>8.20 次</strong>，主要反映對於進口設備與能源設施成本增加的擔憂。</li>
<li><strong><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/120340/us-the-number-of-mentions-of-tariff-in-all-industry">原材料</a></strong> 與 <strong><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/120340/us-the-number-of-mentions-of-tariff-in-all-industry">工業</a></strong> 依然維持在高關注水位（分別為 6.25 次與 6.17 次），企業多提到正在尋找替代供應鏈以規避對中關稅。</li>
</ul>
<h3>三、 MM 研究員觀點：AI 變現與成本轉嫁</h3>
<p>總結過去兩年的趨勢，我們認為投資者應關注以下兩點：</p>
<ol>
<li><strong>AI 紅利從「口號」轉向「實質」</strong>：如 Alphabet 和 Meta 的財報顯示，AI 已經開始帶動搜尋與廣告營收。投資者可透過 <a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/stocks/screener">美股財報資料庫</a> 追蹤企業的資本支出 (CAPEX) 是否轉化為營收成長。</li>
<li><strong>毛利率的防禦戰</strong>：隨着關稅提及次數增加，企業如何轉嫁成本給消費者將是關鍵。根據我們在 <a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/etf/us/screener">美國 ETF 專區</a> 中觀察到的傳統產業表現，具備品牌溢價的公司通常能更好應對關稅衝擊。</li>
</ol>
<p>若您想進一步瞭解相關產業標的，歡迎參考 <a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/etf/tw/screener">台灣 ETF 專區</a> 獲取最新配置靈感。</p>
<p>參考資料：</p>
<ul>
<li>
<p><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/115843/us-sp500-earning-call-keyword-ai">美國-S&amp;P 500電話會議提及次數-人工智慧</a><br />
<a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/115843/us-sp500-earning-call-keyword-ai"><img style="max-width: 100%; height: auto;" alt="" src="https://cdn.macromicro.me/files/charts/843/115843-tc.png" /></a></p>
</li>
<li>
<p><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/120339/us-sp500-earning-call-keyword-tariff">美國-S&amp;P 500電話會議提及次數-關稅</a><br />
<a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/120339/us-sp500-earning-call-keyword-tariff"><img style="max-width: 100%; height: auto;" alt="" src="https://cdn.macromicro.me/files/charts/339/120339-tc.png" /></a></p>
</li>
<li>
<p><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/114367/us-the-number-of-mentions-of-ai-in-all-industry">美國-S&amp;P 500電話會議各產業提及次數-人工智慧</a><br />
<a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/114367/us-the-number-of-mentions-of-ai-in-all-industry"><img style="max-width: 100%; height: auto;" alt="" src="https://cdn.macromicro.me/files/charts/367/114367-tc.png" /></a></p>
</li>
<li><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/blog/market-update-who-will-benefit-from-the-ai-boom-the-financial-reports-of-industry-giants-have-already-provided-the-answer">【行情快報】AI 紅利誰受惠？巨頭財報已給答案！</a></li>
<li><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/quickie?id=2154">【美國】亞馬遜 Amazon 2025Q4 電話會議：AWS 成長率加速並創高，2026 年資本支出將大幅增加</a></li>
</ul>

'''

# %%
import markdown
md = markdown.Markdown(extensions=['tables', 'nl2br'])
response_html = md.convert(response_text)
# Out:
# '<hr />\n<p>過去兩年<br />\n美國S&amp;P500電話會議提及次數</p>\n<hr />\n<p>針對您詢問過去兩年（2024 - 2026 年初）美國 S&P 500 企業電話會議的關鍵字提及次數，我們透過量化分析財報逐字稿發現，市場焦點已從「通膨與衰退」轉向「<strong>AI 變現能力</strong>」與「<strong>關稅政策衝擊</strong>」。</p>\n<p>以下根據最新數據與我們研究員的分析，為您整理關鍵趨勢：</p>\n<h3>一、 核心關鍵字提及次數趨勢</h3>\n<p>在過去兩年的財報季中，企業高層最關注的三大主題分別為：人工智慧、關稅與選舉。這反映了企業在技術轉型與政策變動雙重壓力下的應對策略。</p>\n<table>\n<thead>\n<tr>\n<th>關鍵字主題</th>\n<th>前值 (2025-07-01)</th>\n<th>最新數據 (2025-10-01)</th>\n<th>趨勢分析</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td><strong><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/115843/us-sp500-earning-call-keyword-ai">人工智慧 (AI)</a></strong></td>\n<td>10.89 次</td>\n<td><strong>11.16 次</strong></td>\n<td>持續攀升，顯示 AI 已從實驗轉向核心戰略。</td>\n</tr>\n<tr>\n<td><strong><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/120339/us-sp500-earning-call-keyword-tariff">關稅 (Tariff)</a></strong></td>\n<td>4.35 次</td>\n<td><strong>3.35 次</strong></td>\n<td>處於歷史高位，企業高度關注貿易保護主義。</td>\n<
# ...

# %%
from IPython.display import HTML
HTML(response_html)
# Out:
# <hr />
# <p>過去兩年<br />
# 美國S&amp;P500電話會議提及次數</p>
# <hr />
# <p>針對您詢問過去兩年（2024 - 2026 年初）美國 S&P 500 企業電話會議的關鍵字提及次數，我們透過量化分析財報逐字稿發現，市場焦點已從「通膨與衰退」轉向「<strong>AI 變現能力</strong>」與「<strong>關稅政策衝擊</strong>」。</p>
# <p>以下根據最新數據與我們研究員的分析，為您整理關鍵趨勢：</p>
# <h3>一、 核心關鍵字提及次數趨勢</h3>
# <p>在過去兩年的財報季中，企業高層最關注的三大主題分別為：人工智慧、關稅與選舉。這反映了企業在技術轉型與政策變動雙重壓力下的應對策略。</p>
# <table>
# <thead>
# <tr>
# <th>關鍵字主題</th>
# <th>前值 (2025-07-01)</th>
# <th>最新數據 (2025-10-01)</th>
# <th>趨勢分析</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><strong><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/115843/us-sp500-earning-call-keyword-ai">人工智慧 (AI)</a></strong></td>
# <td>10.89 次</td>
# <td><strong>11.16 次</strong></td>
# <td>持續攀升，顯示 AI 已從實驗轉向核心戰略。</td>
# </tr>
# <tr>
# <td><strong><a target="_blank" rel="noopener noreferrer" href="https://www.macromicro.me/charts/120339/us-sp500-earning-call-keyword-tariff">關稅 (Tariff)</a></strong></td>
# <td>4.35 次</td>
# <td><strong>3.35 次</strong></td>
# ...
