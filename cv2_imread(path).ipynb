# %% [markdown]
# <a href="https://colab.research.google.com/github/x1001000/Colab-Notebooks/blob/master/cv2_imread(path).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://a.ksd-i.com/a/2021-09-23/137621-919775.jpg
# Out:
# --2021-10-06 06:36:36--  https://a.ksd-i.com/a/2021-09-23/137621-919775.jpg
# Resolving a.ksd-i.com (a.ksd-i.com)... 54.239.152.29, 54.239.152.10, 54.239.152.42, ...
# Connecting to a.ksd-i.com (a.ksd-i.com)|54.239.152.29|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 232300 (227K) [image/jpeg]
# Saving to: ‘137621-919775.jpg’
#
# 137621-919775.jpg   100%[===================>] 226.86K   270KB/s    in 0.8s
#
# 2021-10-06 06:36:38 (270 KB/s) - ‘137621-919775.jpg’ saved [232300/232300]

# %%
import cv2
array = cv2.imread('/content/137621-919775.jpg')
array.shape
# Out:
# (1800, 1600, 3)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(array)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x1800 at 0x7F0DAEDEA7D0>
