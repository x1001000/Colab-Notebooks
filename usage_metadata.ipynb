# %% [markdown]
# <a href="https://colab.research.google.com/github/x1001000/Colab-Notebooks/blob/main/usage_metadata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# Please ensure you have imported a Gemini API key from AI Studio.
# You can do this directly in the Secrets tab on the left.
#
# After doing so, please run the setup cell below.

# %%
import os
from google.colab import userdata
from google.colab import drive
os.environ["GEMINI_API_KEY"] = userdata.get("GEMINI_API_KEY")

# %% [markdown]
# # Generated Code

# %%
def generate():
    client = genai.Client(
        api_key=os.environ.get("GEMINI_API_KEY"),
    )

    model = "gemini-2.5-flash"
    contents = [
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""今天台股加權指數"""),
            ],
        ),
        types.Content(
            role="model",
            parts=[
                types.Part.from_text(text="""**Analyzing Market Indicators**

I've initiated the data gathering process. I'm currently running searches for \"今天台股加權指數\" and \"台灣 加權股價指數\" on Google to fetch the most recent data. The next step involves extracting pertinent information – index value, change, and percentage change – before formulating a concise response.


**Refining Data Acquisition**

I'm now zeroing in on data extraction. My focus is on pulling out the index value, change, and percentage change. I plan to use the retrieved data from the Google searches to formulate a simple, clear answer to the user's query about today's TAIEX.


"""),
            ],
        ),
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""今天台股加權指數"""),
            ],
        ),
        types.Content(
            role="model",
            parts=[
                types.Part.from_text(text="""**Analyzing Market Indicators**

I've initiated the data gathering process. I'm currently running searches for \"今天台股加權指數\" and \"台灣 加權股價指數\" on Google to fetch the most recent data. The next step involves extracting pertinent information – index value, change, and percentage change – before formulating a concise response.


**Refining Data Acquisition**

I'm now zeroing in on data extraction. My focus is on pulling out the index value, change, and percentage change. I plan to use the retrieved data from the Google searches to formulate a simple, clear answer to the user's query about today's TAIEX.


"""),
            ],
        ),
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""今天台股加權指數"""),
            ],
        ),
        types.Content(
            role="model",
            parts=[
                types.Part.from_text(text="""**Analyzing Market Indicators**

I've initiated the data gathering process. I'm currently running searches for \"今天台股加權指數\" and \"台灣 加權股價指數\" on Google to fetch the most recent data. The next step involves extracting pertinent information – index value, change, and percentage change – before formulating a concise response.


**Refining Data Acquisition**

I'm now zeroing in on data extraction. My focus is on pulling out the index value, change, and percentage change. I plan to use the retrieved data from the Google searches to formulate a simple, clear answer to the user's query about today's TAIEX.


"""),
            ],
        ),
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""今天台股加權指數"""),
            ],
        ),
        types.Content(
            role="model",
            parts=[
                types.Part.from_text(text="""**Analyzing Market Indicators**

I've initiated the data gathering process. I'm currently running searches for \"今天台股加權指數\" and \"台灣 加權股價指數\" on Google to fetch the most recent data. The next step involves extracting pertinent information – index value, change, and percentage change – before formulating a concise response.


**Refining Data Acquisition**

I'm now zeroing in on data extraction. My focus is on pulling out the index value, change, and percentage change. I plan to use the retrieved data from the Google searches to formulate a simple, clear answer to the user's query about today's TAIEX.


"""),
            ],
        ),
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""今天台股加權指數"""),
            ],
        ),
        types.Content(
            role="model",
            parts=[
                types.Part.from_text(text="""**Analyzing Market Indicators**

I've initiated the data gathering process. I'm currently running searches for \"今天台股加權指數\" and \"台灣 加權股價指數\" on Google to fetch the most recent data. The next step involves extracting pertinent information – index value, change, and percentage change – before formulating a concise response.


**Refining Data Acquisition**

I'm now zeroing in on data extraction. My focus is on pulling out the index value, change, and percentage change. I plan to use the retrieved data from the Google searches to formulate a simple, clear answer to the user's query about today's TAIEX.


"""),
            ],
        ),
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""今天台股加權指數"""),
            ],
        ),
        types.Content(
            role="model",
            parts=[
                types.Part.from_text(text="""**Analyzing Market Indicators**

I've initiated the data gathering process. I'm currently running searches for \"今天台股加權指數\" and \"台灣 加權股價指數\" on Google to fetch the most recent data. The next step involves extracting pertinent information – index value, change, and percentage change – before formulating a concise response.


**Refining Data Acquisition**

I'm now zeroing in on data extraction. My focus is on pulling out the index value, change, and percentage change. I plan to use the retrieved data from the Google searches to formulate a simple, clear answer to the user's query about today's TAIEX.


"""),
            ],
        ),
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""今天台股加權指數"""),
            ],
        ),
        types.Content(
            role="model",
            parts=[
                types.Part.from_text(text="""**Analyzing Market Indicators**

I've initiated the data gathering process. I'm currently running searches for \"今天台股加權指數\" and \"台灣 加權股價指數\" on Google to fetch the most recent data. The next step involves extracting pertinent information – index value, change, and percentage change – before formulating a concise response.


**Refining Data Acquisition**

I'm now zeroing in on data extraction. My focus is on pulling out the index value, change, and percentage change. I plan to use the retrieved data from the Google searches to formulate a simple, clear answer to the user's query about today's TAIEX.


"""),
            ],
        ),
        types.Content(
            role="user",
            parts=[
                types.Part.from_text(text="""今天台股加權指數"""),
            ],
        ),
    ]
    tools = [
        types.Tool(googleSearch=types.GoogleSearch(
        )),
    ]
    generate_content_config = types.GenerateContentConfig(
        thinking_config = types.ThinkingConfig(
            thinking_budget=-1,
        ),
        tools=tools,
    )

    response = client.models.generate_content(
        model=model,
        contents=contents,
        config=generate_content_config,
    )
    return response

# %%
r = generate()
r.text
# Out:
# '截至2025年8月26日收盤，台灣加權股價指數（TAIEX）收在24305.10點，上漲27.72點，漲幅0.11%。'

# %%
usage_metadata = r.usage_metadata.model_dump()
usage_metadata
# Out:
# {'cache_tokens_details': [{'modality': <MediaModality.TEXT: 'TEXT'>,
#    'token_count': 134}],
#  'cached_content_token_count': 134,
#  'candidates_token_count': 78,
#  'candidates_tokens_details': None,
#  'prompt_token_count': 1036,
#  'prompt_tokens_details': [{'modality': <MediaModality.TEXT: 'TEXT'>,
#    'token_count': 1036}],
#  'thoughts_token_count': 276,
#  'tool_use_prompt_token_count': 1100,
#  'tool_use_prompt_tokens_details': [{'modality': <MediaModality.TEXT: 'TEXT'>,
#    'token_count': 1100}],
#  'total_token_count': 2490,
#  'traffic_type': None}

# %%
print('輸入', usage_metadata.get('prompt_token_count'))
print('快取', usage_metadata.get('cached_content_token_count'))
print('思考', usage_metadata.get('thoughts_token_count'))
print('工具', usage_metadata.get('tool_use_prompt_token_count'))
print('輸出', usage_metadata.get('candidates_token_count'))
print('加總', usage_metadata.get('total_token_count'))
# Out:
# 輸入 1036
# 快取 134
# 思考 276
# 工具 1100
# 輸出 78
# 加總 2490
