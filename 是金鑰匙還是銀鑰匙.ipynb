# %% [markdown]
# <a href="https://colab.research.google.com/github/x1001000/Colab-Notebooks/blob/main/%E6%98%AF%E9%87%91%E9%91%B0%E5%8C%99%E9%82%84%E6%98%AF%E9%8A%80%E9%91%B0%E5%8C%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
from getpass import getpass
client = genai.Client(api_key=getpass())
# Out:
# ··········

# %%
client.models.generate_content(
    model='gemini-2.5-pro',
    contents='哈囉',
).text
# Out:
# '哈囉！你好呀 👋\n\n請問有什麼我可以幫忙的嗎？'
